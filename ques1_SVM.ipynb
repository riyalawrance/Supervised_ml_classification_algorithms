# %% [markdown]
# <h1>Hard margin SVM</h1>

# %% [markdown]
# <h3>Test Size:0.2</h3>

# %%
# Importing the required packages
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn import svm
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Diabetes.csv')

# Assuming the last column is the target (label) and the rest are features
X = data.iloc[:, :-1]  # All rows, all columns except the last (features)
y = data.iloc[:, -1]   # All rows, only the last column (target)

# Split the dataset into training and testing sets
X_train, X_test, y2_train, y2_test = train_test_split(X, y, test_size=0.2)

#Initialise Decision Tree Classifier
clf = svm.SVC(kernel='linear', C = 10000, max_iter = 100000)

#Train the model
clf = clf.fit(X_train, y2_train)

# Make predictions
y2_pred = clf.predict(X_test)

# Evaluate the model
accuracy2 = accuracy_score(y2_test, y2_pred)
print("Accuracy:", accuracy2)
print("Classification Report:\n", classification_report(y2_test, y2_pred))

# Compute confusion matrix
cm = confusion_matrix(y2_test, y2_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')  # Optional: Change colormap
plt.show()
# Out:
# Accuracy: 0.2922077922077922
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.40      0.22      0.29        98
#            1       0.23      0.41      0.30        56
#
#     accuracy                           0.29       154
#    macro avg       0.32      0.32      0.29       154
# weighted avg       0.34      0.29      0.29       154
# C:\Users\riyal\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %% [markdown]
# <h3>Test Size:0.3</h3>

# %%
# Importing the required packages
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn import svm
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Diabetes.csv')

# Assuming the last column is the target (label) and the rest are features
X = data.iloc[:, :-1]  # All rows, all columns except the last (features)
y = data.iloc[:, -1]   # All rows, only the last column (target)

# Split the dataset into training and testing sets
X_train, X_test, y3_train, y3_test = train_test_split(X, y, test_size=0.3)

#Initialise Decision Tree Classifier
clf = svm.SVC(kernel='linear', C = 10000, max_iter = 100000)

#Train the model
clf = clf.fit(X_train, y3_train)

# Make predictions
y3_pred = clf.predict(X_test)

# Evaluate the model
accuracy3 = accuracy_score(y3_test, y3_pred)
print("Accuracy:", accuracy3)
print("Classification Report:\n", classification_report(y3_test, y3_pred))

# Compute confusion matrix
cm = confusion_matrix(y3_test, y3_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')  # Optional: Change colormap
plt.show()
# Out:
# Accuracy: 0.35064935064935066
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.28      0.36       154
#            1       0.26      0.49      0.34        77
#
#     accuracy                           0.35       231
#    macro avg       0.39      0.39      0.35       231
# weighted avg       0.43      0.35      0.36       231
# C:\Users\riyal\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(

# %% [markdown]
# <h3>Test Size:0.4</h3>

# %%
# Importing the required packages
import numpy as np
import pandas as pd
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report, ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn import svm
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('Diabetes.csv')

# Assuming the last column is the target (label) and the rest are features
X = data.iloc[:, :-1]  # All rows, all columns except the last (features)
y = data.iloc[:, -1]   # All rows, only the last column (target)

# Split the dataset into training and testing sets
X_train, X_test, y4_train, y4_test = train_test_split(X, y, test_size=0.4)

#Initialise Decision Tree Classifier
clf = svm.SVC(kernel='linear', C = 10000, max_iter = 100000)

#Train the model
clf = clf.fit(X_train, y4_train)

# Make predictions
y4_pred = clf.predict(X_test)

# Evaluate the model
accuracy4 = accuracy_score(y4_test, y4_pred)
print("Accuracy:", accuracy4)
print("Classification Report:\n", classification_report(y4_test, y4_pred))

# Compute confusion matrix
cm = confusion_matrix(y4_test, y4_pred)

# Display confusion matrix
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot(cmap='Blues')  # Optional: Change colormap
plt.show()
# Out:
# C:\Users\riyal\anaconda3\Lib\site-packages\sklearn\svm\_base.py:297: ConvergenceWarning: Solver terminated early (max_iter=100000).  Consider pre-processing your data with StandardScaler or MinMaxScaler.
#   warnings.warn(
# Accuracy: 0.5746753246753247
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.71      0.59      0.64       201
#            1       0.41      0.54      0.47       107
#
#     accuracy                           0.57       308
#    macro avg       0.56      0.57      0.56       308
# weighted avg       0.61      0.57      0.58       308

# %%
from IPython.display import display
import pandas as pd

dict = {'Test Size' : [0.2,0.3,0.4],
        'Accuracy' : [ accuracy2,accuracy3,accuracy4]}

df = pd.DataFrame(dict)
display(df)

print("Classification Report(Test Size:0.2):\n", classification_report(y2_test, y2_pred))
print("Classification Report(Test Size:0.3):\n", classification_report(y3_test, y3_pred))
print("Classification Report(Test Size:0.4):\n", classification_report(y4_test, y4_pred))
# Out:
#    Test Size  Accuracy
# 0        0.2  0.292208
# 1        0.3  0.350649
# 2        0.4  0.574675
# Classification Report(Test Size:0.2):
#                precision    recall  f1-score   support
#
#            0       0.40      0.22      0.29        98
#            1       0.23      0.41      0.30        56
#
#     accuracy                           0.29       154
#    macro avg       0.32      0.32      0.29       154
# weighted avg       0.34      0.29      0.29       154
#
# Classification Report(Test Size:0.3):
#                precision    recall  f1-score   support
#
#            0       0.52      0.28      0.36       154
#            1       0.26      0.49      0.34        77
#
#     accuracy                           0.35       231
#    macro avg       0.39      0.39      0.35       231
# weighted avg       0.43      0.35      0.36       231
#
# Classification Report(Test Size:0.4):
#                precision    recall  f1-score   support
#
#            0       0.71      0.59      0.64       201
#            1       0.41      0.54      0.47       107
#
#     accuracy                           0.57       308
#    macro avg       0.56      0.57      0.56       308
# weighted avg       0.61      0.57      0.58       308
